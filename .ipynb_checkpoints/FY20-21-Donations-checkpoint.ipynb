# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

step2 = "Fundraising Strategy - Step 2, 07.21.20.csv"
donation_data = pd.read_csv(step2)
donation_data
# Out:
#                                 Campaign Name                Bucket  \
# 0                           Sponsor a Scholar  1: Individual Giving
# 1             Sponsor a Scholar - Fund a Thon  1: Individual Giving
# 2                               Appeal - June  1: Individual Giving
# 3                           Appeal - December  1: Individual Giving
# 4              Online appeal - Giving Tuesday  1: Individual Giving
# 5              Online event - Starfish Search  1: Individual Giving
# 6   Online event - Starfish Bracket Challenge  1: Individual Giving
# 7                               Lapsed Donors  1: Individual Giving
# 8                      Benefit dinner tickets  1: Individual Giving
# 9         Benefit dinner individual donations  1: Individual Giving
# 10                     Benefit dinner auction  1: Individual Giving
# 11                             Events - CT/NE  1: Individual Giving
# 12                     Events - not recurring  1: Individual Giving
# 13                           Events - Ecuador  1: Individual Giving
# 14                     Birthdays and weddings  1: Individual Giving
# 15                          Unsolicited Gifts  1: Individual Giving
# 16            Benefit dinner sponsorships (5)       2: Major Donors
# 17                         University Efforts       2: Major Donors
# 18                                     Grants             3: Grants
# 19            Benefit dinner sponsorships (1)       4: Corporations
# 20                    Matching donations (10)       4: Corporations
# 21                         Ecua vols/visitors     5: Earned Revenue
# 22                  Benefit dinner item sales     5: Earned Revenue
# 23                            Pura Vida sales     5: Earned Revenue
# 24                           Dream Book sales     5: Earned Revenue
# 25                            Popsocket sales     5: Earned Revenue
# 26                                Photo sales     5: Earned Revenue
# 27                            Speaking events     5: Earned Revenue
# 28                               Amazon Smile     5: Earned Revenue
# 29                                  CafePress     5: Earned Revenue
# 30                                   Goodshop     5: Earned Revenue
# 31                                        NaN                   NaN
# 32                               Thank-a-thon             No bucket
# 33                          4th quarter press             No bucket
#
#     Income FY21 In-Kind Donations FY21  Volunteer Hours FY21  Income FY20  \
# 0   $12,420.45                  $0.00                   30.0  $25,213.95
# 1           NaN                 $0.00                    NaN   $3,610.00
# 2    $9,641.00                  $0.00                   27.0  $25,295.00
# 3           NaN                 $0.00                    NaN   $9,637.11
# 4           NaN                 $0.00                    NaN   $8,544.94
# 5           NaN                 $0.00                    NaN   $1,268.00
# 6           NaN                 $0.00                    5.0   $1,115.00
# 7           NaN                 $0.00                    NaN     $400.00
# 8    $1,919.10                $140.00                  298.0   $2,898.02
# 9    $7,596.29                  $0.00                    0.0     $654.11
# 10   $9,808.13              $2,164.97                   14.0       $0.00
# 11          NaN                 $0.00                    NaN     $309.00
# 12     $309.30                  $0.00                    0.0   $2,920.00
# 13       $0.00                  $0.00                    0.0   $1,213.60
# 14   $1,667.52                  $0.00                    3.0   $6,049.31
# 15   $5,178.48                  $0.00                    3.0  $30,005.66
# 16   $3,000.00                  $0.00                    3.0  $47,000.00
# 17          NaN                 $0.00                    1.0   $1,016.00
# 18     $750.00                  $0.00                    6.0       $0.00
# 19     $520.56                  $0.00                    1.0       $0.00
# 20   $2,413.26                  $0.00                    6.0   $1,769.19
# 21       $0.00                  $0.00                    0.0   $5,487.46
# 22     $514.62                  $0.00                    1.0      $86.44
# 23       $5.00                  $0.00                    1.0       $5.00
# 24       $0.00                  $0.00                    1.0       $0.00
# 25       $0.00                  $0.00                    1.0       $0.00
# 26       $0.00                  $0.00                    1.0      $40.00
# 27       $0.00                  $0.00                    0.0     $414.00
# 28      $32.35                  $0.00                    1.0     $192.33
# 29       $0.00                  $0.00                    0.0       $0.00
# 30       $0.00                  $0.00                    0.0       $0.00
# 31          NaN                    NaN                   NaN          NaN
# 32          NaN                    NaN                   NaN          NaN
# 33          NaN                    NaN                   NaN          NaN
#
#    In-Kind Donations FY20  Volunteer Hours FY20
# 0                  $0.00                   75.0
# 1                  $3.50                   20.0
# 2                $341.23                   20.0
# 3                $459.55                   20.0
# 4              $1,499.08                   36.0
# 5                  $7.50                   50.0
# 6                $230.00                   30.0
# 7                  $0.00                    8.0
# 8                $244.79                  240.0
# 9                  $0.00                    0.0
# 10             $7,078.09                  138.0
# 11                $22.00                   10.0
# 12             $3,578.27                   60.0
# 13                 $0.00                   80.0
# 14                 $0.00                    3.0
# 15                 $0.00                    3.0
# 16                 $0.00                   54.0
# 17                 $0.00                    1.0
# 18                 $0.00                    1.0
# 19                 $0.00                    0.0
# 20                 $0.00                    6.0
# 21                 $0.00                    NaN
# 22               $704.94                   10.0
# 23                 $0.00                    1.0
# 24                 $0.00                   10.0
# 25                 $0.00                    1.0
# 26                 $0.00                   10.0
# 27                 $0.00                    4.0
# 28                 $0.00                    1.0
# 29                 $0.00                    0.0
# 30                 $0.00                    0.0
# 31                    NaN                   NaN
# 32                    NaN                   NaN
# 33                    NaN                   NaN

# %%
FY20_donations = donation_data[['Campaign Name', 'Bucket', 'Income FY20', 'In-Kind Donations FY20', 'Volunteer Hours FY20']]
FY20_donations[FY20_donations.columns[2:7]] = FY20_donations[FY20_donations.columns[2:7]].replace('[\$,]', '', regex=True).astype(float)
FY20_donations
# Out:
# C:\Users\Purvi Patel\Anaconda3\lib\site-packages\pandas\core\frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                                 Campaign Name                Bucket  \
# 0                           Sponsor a Scholar  1: Individual Giving
# 1             Sponsor a Scholar - Fund a Thon  1: Individual Giving
# 2                               Appeal - June  1: Individual Giving
# 3                           Appeal - December  1: Individual Giving
# 4              Online appeal - Giving Tuesday  1: Individual Giving
# 5              Online event - Starfish Search  1: Individual Giving
# 6   Online event - Starfish Bracket Challenge  1: Individual Giving
# 7                               Lapsed Donors  1: Individual Giving
# 8                      Benefit dinner tickets  1: Individual Giving
# 9         Benefit dinner individual donations  1: Individual Giving
# 10                     Benefit dinner auction  1: Individual Giving
# 11                             Events - CT/NE  1: Individual Giving
# 12                     Events - not recurring  1: Individual Giving
# 13                           Events - Ecuador  1: Individual Giving
# 14                     Birthdays and weddings  1: Individual Giving
# 15                          Unsolicited Gifts  1: Individual Giving
# 16            Benefit dinner sponsorships (5)       2: Major Donors
# 17                         University Efforts       2: Major Donors
# 18                                     Grants             3: Grants
# 19            Benefit dinner sponsorships (1)       4: Corporations
# 20                    Matching donations (10)       4: Corporations
# 21                         Ecua vols/visitors     5: Earned Revenue
# 22                  Benefit dinner item sales     5: Earned Revenue
# 23                            Pura Vida sales     5: Earned Revenue
# 24                           Dream Book sales     5: Earned Revenue
# 25                            Popsocket sales     5: Earned Revenue
# 26                                Photo sales     5: Earned Revenue
# 27                            Speaking events     5: Earned Revenue
# 28                               Amazon Smile     5: Earned Revenue
# 29                                  CafePress     5: Earned Revenue
# 30                                   Goodshop     5: Earned Revenue
# 31                                        NaN                   NaN
# 32                               Thank-a-thon             No bucket
# 33                          4th quarter press             No bucket
#
#     Income FY20  In-Kind Donations FY20  Volunteer Hours FY20
# 0      25213.95                    0.00                  75.0
# 1       3610.00                    3.50                  20.0
# 2      25295.00                  341.23                  20.0
# 3       9637.11                  459.55                  20.0
# 4       8544.94                 1499.08                  36.0
# 5       1268.00                    7.50                  50.0
# 6       1115.00                  230.00                  30.0
# 7        400.00                    0.00                   8.0
# 8       2898.02                  244.79                 240.0
# 9        654.11                    0.00                   0.0
# 10         0.00                 7078.09                 138.0
# 11       309.00                   22.00                  10.0
# 12      2920.00                 3578.27                  60.0
# 13      1213.60                    0.00                  80.0
# 14      6049.31                    0.00                   3.0
# 15     30005.66                    0.00                   3.0
# 16     47000.00                    0.00                  54.0
# 17      1016.00                    0.00                   1.0
# 18         0.00                    0.00                   1.0
# 19         0.00                    0.00                   0.0
# 20      1769.19                    0.00                   6.0
# 21      5487.46                    0.00                   NaN
# 22        86.44                  704.94                  10.0
# 23         5.00                    0.00                   1.0
# 24         0.00                    0.00                  10.0
# 25         0.00                    0.00                   1.0
# 26        40.00                    0.00                  10.0
# 27       414.00                    0.00                   4.0
# 28       192.33                    0.00                   1.0
# 29         0.00                    0.00                   0.0
# 30         0.00                    0.00                   0.0
# 31          NaN                     NaN                   NaN
# 32          NaN                     NaN                   NaN
# 33          NaN                     NaN                   NaN

# %%
Total_Income = FY20_donations['Income FY20'].sum()
Total_InKind = FY20_donations['In-Kind Donations FY20'].sum()
Total_VolHours = FY20_donations['Volunteer Hours FY20'].sum()

FY20_donations['Income_Percentage'] = round(FY20_donations['Income FY20']/Total_Income,3)
FY20_donations['InKind_Percentage'] = round(FY20_donations['In-Kind Donations FY20']/Total_InKind,3)
FY20_donations['VolHours_Percentage'] = round(FY20_donations['Volunteer Hours FY20']/Total_VolHours,3)
FY20_donations.head()
# Out:
#                      Campaign Name                Bucket  Income FY20  \
# 0                Sponsor a Scholar  1: Individual Giving     25213.95
# 1  Sponsor a Scholar - Fund a Thon  1: Individual Giving      3610.00
# 2                    Appeal - June  1: Individual Giving     25295.00
# 3                Appeal - December  1: Individual Giving      9637.11
# 4   Online appeal - Giving Tuesday  1: Individual Giving      8544.94
#
#    In-Kind Donations FY20  Volunteer Hours FY20  Income_Percentage  \
# 0                    0.00                  75.0              0.144
# 1                    3.50                  20.0              0.021
# 2                  341.23                  20.0              0.144
# 3                  459.55                  20.0              0.055
# 4                 1499.08                  36.0              0.049
#
#    InKind_Percentage  VolHours_Percentage
# 0              0.000                0.084
# 1              0.000                0.022
# 2              0.024                0.022
# 3              0.032                0.022
# 4              0.106                0.040

# %%
FY20_by_bucket = FY20_donations.groupby(['Bucket'])
FY20_bucket_totals = FY20_by_bucket.sum()
FY20_bucket_totals = FY20_bucket_totals[["Income FY20", "Income_Percentage", "In-Kind Donations FY20", "InKind_Percentage", "Volunteer Hours FY20", "VolHours_Percentage"]]

# FORMATTING
FY20_bucket_totals["Income FY20"] = FY20_bucket_totals["Income FY20"].map("${:,.2f}".format)
FY20_bucket_totals["In-Kind Donations FY20"] = FY20_bucket_totals["In-Kind Donations FY20"].map("${:,.2f}".format)
FY20_bucket_totals["Income_Percentage"] = FY20_bucket_totals["Income_Percentage"].map("{:,.1%}".format)
FY20_bucket_totals["InKind_Percentage"] = FY20_bucket_totals["InKind_Percentage"].map("{:,.1%}".format)
FY20_bucket_totals["VolHours_Percentage"] = FY20_bucket_totals["VolHours_Percentage"].map("{:,.1%}".format)

FY20_bucket_totals.to_csv("./Excel/Buckets-FY20-totals.csv", encoding="utf-8", index=True)
FY20_bucket_totals
# Out:
#                       Income FY20 Income_Percentage In-Kind Donations FY20  \
# Bucket
# 1: Individual Giving  $119,133.70             68.1%             $13,464.01
# 2: Major Donors        $48,016.00             27.4%                  $0.00
# 3: Grants                   $0.00              0.0%                  $0.00
# 4: Corporations         $1,769.19              1.0%                  $0.00
# 5: Earned Revenue       $6,225.23              3.4%                $704.94
# No bucket                   $0.00              0.0%                  $0.00
#
#                      InKind_Percentage  Volunteer Hours FY20  \
# Bucket
# 1: Individual Giving             95.1%                 793.0
# 2: Major Donors                   0.0%                  55.0
# 3: Grants                         0.0%                   1.0
# 4: Corporations                   0.0%                   6.0
# 5: Earned Revenue                 5.0%                  37.0
# No bucket                         0.0%                   0.0
#
#                      VolHours_Percentage
# Bucket
# 1: Individual Giving               88.7%
# 2: Major Donors                     6.2%
# 3: Grants                           0.1%
# 4: Corporations                     0.7%
# 5: Earned Revenue                   4.0%
# No bucket                           0.0%

# %%
FY20_bucket_ave = FY20_by_bucket.mean()
FY20_bucket_ave = FY20_bucket_ave.drop(['Income_Percentage','InKind_Percentage','VolHours_Percentage'], axis=1)
FY20_bucket_ave["Income FY20"] = FY20_bucket_ave["Income FY20"].map("${:,.2f}".format)
FY20_bucket_ave["In-Kind Donations FY20"] = FY20_bucket_ave["In-Kind Donations FY20"].map("${:,.2f}".format)
FY20_bucket_ave["Volunteer Hours FY20"] = FY20_bucket_ave["Volunteer Hours FY20"].map("{:.1f}".format)

FY20_bucket_ave.to_csv("./Excel/Buckets-FY20-avg.csv", encoding="utf-8", index=True)
FY20_bucket_ave
# Out:
#                      Income FY20 In-Kind Donations FY20 Volunteer Hours FY20
# Bucket
# 1: Individual Giving   $7,445.86                $841.50                 49.6
# 2: Major Donors       $24,008.00                  $0.00                 27.5
# 3: Grants                  $0.00                  $0.00                  1.0
# 4: Corporations          $884.60                  $0.00                  3.0
# 5: Earned Revenue        $622.52                 $70.49                  4.1
# No bucket                   $nan                   $nan                  nan

# %%
FY21_FY20 = donation_data
FY21_FY20[FY21_FY20.columns[2:7]] = FY21_FY20[FY21_FY20.columns[2:7]].replace('[\$,]', '', regex=True).astype(float)

FY21_FY20_buckets = FY21_FY20.groupby(['Bucket'])
FY21vFY20_to_date = FY21_FY20_buckets.sum()
FY21vFY20_to_date = FY21vFY20_to_date[['Income FY21', 'Income FY20', 'In-Kind Donations FY21', 'In-Kind Donations FY20', 'Volunteer Hours FY21', 'Volunteer Hours FY20']]

FY21vFY20_to_date["Income FY21"] = FY21vFY20_to_date["Income FY21"].map("${:,.2f}".format)
FY21vFY20_to_date["In-Kind Donations FY21"] = FY21vFY20_to_date["In-Kind Donations FY21"].map("${:,.2f}".format)
FY21vFY20_to_date["Income FY20"] = FY21vFY20_to_date["Income FY20"].map("${:,.2f}".format)
FY21vFY20_to_date["In-Kind Donations FY20"] = FY21vFY20_to_date["In-Kind Donations FY20"].map("${:,.2f}".format)

# FY21vFY20_to_date.to_csv("./Excel/FY21vFY20_to_date_7.21.20.csv", encoding="utf-8", index=True)
FY21vFY20_to_date
# Out:
#                      Income FY21  Income FY20 In-Kind Donations FY21  \
# Bucket
# 1: Individual Giving  $48,540.27  $119,133.70              $2,304.97
# 2: Major Donors        $3,000.00   $48,016.00                  $0.00
# 3: Grants                $750.00        $0.00                  $0.00
# 4: Corporations        $2,933.82    $1,769.19                  $0.00
# 5: Earned Revenue        $551.97    $6,225.23                  $0.00
# No bucket                  $0.00        $0.00                  $0.00
#
#                      In-Kind Donations FY20  Volunteer Hours FY21  \
# Bucket
# 1: Individual Giving             $13,464.01                 380.0
# 2: Major Donors                       $0.00                   4.0
# 3: Grants                             $0.00                   6.0
# 4: Corporations                       $0.00                   7.0
# 5: Earned Revenue                   $704.94                   6.0
# No bucket                             $0.00                   0.0
#
#                       Volunteer Hours FY20
# Bucket
# 1: Individual Giving                 793.0
# 2: Major Donors                       55.0
# 3: Grants                              1.0
# 4: Corporations                        6.0
# 5: Earned Revenue                     37.0
# No bucket                              0.0

# %%
FY21vFY20_campaigns = donation_data.dropna(how='any')
FY21vFY20_campaigns = FY21vFY20_campaigns[['Bucket', 'Campaign Name', 'Income FY21', 'Income FY20']]

# FY21vFY20_campaigns.to_csv("./Excel/FY21vFY20_campaigns_7.21.20.csv", encoding="utf-8", index=True)
FY21vFY20_campaigns
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-ae0c36815c07> in <module>
#       2 FY21vFY20_campaigns = FY21vFY20_campaigns[['Bucket', 'Campaign Name', 'Income FY21', 'Income FY20']]
#       3
# ----> 4 FY21vFY20_campaigns.to_csv("./Excel/FY21vFY20_campaigns_7.21.20.csv", encoding="utf-8", index=True)
#       5 FY21vFY20_campaigns
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: './Excel/FY21vFY20_campaigns_7.21.20.csv'
