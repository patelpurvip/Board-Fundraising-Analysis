# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sb
sb.set()

step2 = "Sources/Fundraising Strategy - Step 2, 08.07.20.csv"
donation_data = pd.read_csv(step2)
# donation_data.head()

# %% [markdown]
# # Data Import

# %%
expenses_import = "Sources/Advancement Calendar - FY21 calendar, 08.08.20.csv"
expenses_data = pd.read_csv(expenses_import)
expenses = expenses_data[['Event', 'Expenses FY21', 'Expenses FY20', 'Funds Raised FY20']]

expenses = expenses.rename(columns={"Event": "Campaign Name"})
expenses.head()
# Out:
#                                        Campaign Name Expenses FY21  \
# 0  Benefit Dinner (occuring April 2020) (SPANS TW...       $250.00
# 1                    Sponsor a Scholar - Fund a Thon         $0.00
# 2                                      Appeal - June       $210.06
# 3                                 Ecua vols/visitors         $0.00
# 4                     Online event - Starfish Search         $0.00
#
#   Expenses FY20 Funds Raised FY20
# 0     $3,220.00        $65,987.57
# 1         $0.00         $3,610.00
# 2         $0.00        $25,295.00
# 3        $25.00         $5,487.46
# 4       $302.00         $1,268.00

# %%
income_vs_expense = pd.merge(donation_data, expenses, how="outer", on='Campaign Name')
income_vs_expense = income_vs_expense[['Bucket', 'Campaign Name', 'Expenses FY21', 'Income FY21', 'In-Kind Donations FY21', 'Volunteer Hours FY21', 'Expenses FY20', 'Income FY20', 'In-Kind Donations FY20', 'Volunteer Hours FY20']]
income_vs_expense
# Out:
#                   Bucket                                      Campaign Name  \
# 0   1: Individual Giving                                  Sponsor a Scholar
# 1   1: Individual Giving                    Sponsor a Scholar - Fund a Thon
# 2   1: Individual Giving                                      Appeal - June
# 3   1: Individual Giving                                  Appeal - December
# 4   1: Individual Giving                     Online appeal - Giving Tuesday
# 5   1: Individual Giving                     Online event - Starfish Search
# 6   1: Individual Giving          Online event - Starfish Bracket Challenge
# 7   1: Individual Giving                                      Lapsed Donors
# 8   1: Individual Giving                             Benefit dinner tickets
# 9   1: Individual Giving                Benefit dinner individual donations
# 10  1: Individual Giving                             Benefit dinner auction
# 11  1: Individual Giving                                     Events - CT/NE
# 12  1: Individual Giving                             Events - not recurring
# 13  1: Individual Giving                                   Events - Ecuador
# 14  1: Individual Giving                             Birthdays and weddings
# 15  1: Individual Giving                                  Unsolicited Gifts
# 16       2: Major Donors                    Benefit dinner sponsorships (5)
# 17       2: Major Donors                                 University Efforts
# 18             3: Grants                                             Grants
# 19       4: Corporations                    Benefit dinner sponsorships (1)
# 20       4: Corporations                            Matching donations (10)
# 21     5: Earned Revenue                                 Ecua vols/visitors
# 22     5: Earned Revenue                          Benefit dinner item sales
# 23     5: Earned Revenue                                    Pura Vida sales
# 24     5: Earned Revenue                                   Dream Book sales
# 25     5: Earned Revenue                                    Popsocket sales
# 26     5: Earned Revenue                                        Photo sales
# 27     5: Earned Revenue                                    Speaking events
# 28     5: Earned Revenue                                       Amazon Smile
# 29     5: Earned Revenue                                          CafePress
# 30     5: Earned Revenue                                           Goodshop
# 31                   NaN                                                NaN
# 32                   NaN                                                NaN
# 33                   NaN                                                NaN
# 34                   NaN                                                NaN
# 35             No bucket                                       Thank-a-thon
# 36             No bucket                                  4th quarter press
# 37                   NaN  Benefit Dinner (occuring April 2020) (SPANS TW...
# 38                   NaN  Benefit Dinner (occurring in April 2021) (SPAN...
# 39                   NaN  PuraVida bracelets, Dream books, Photo sales, ...
# 40                   NaN                  Amazon Smile, Cafepress, Goodshop
# 41                   NaN  Additional Expenses (not related to an advance...
#
#    Expenses FY21  Income FY21 In-Kind Donations FY21 Volunteer Hours FY21  \
# 0          $0.00   $12,420.45                  $0.00                   30
# 1          $0.00  coming soon                  $0.00          coming soon
# 2        $210.06    $9,641.00                  $0.00                   27
# 3          $0.00  coming soon                  $0.00          coming soon
# 4          $0.00  coming soon                  $0.00          coming soon
# 5          $0.00  coming soon                  $0.00          coming soon
# 6        $175.00  coming soon                  $0.00                    5
# 7          $0.00  coming soon                  $0.00          coming soon
# 8            NaN    $4,817.12                $384.79                  538
# 9            NaN    $8,250.40                  $0.00                    0
# 10           NaN    $9,808.13              $9,243.06                  152
# 11         $0.00  coming soon                  $0.00          coming soon
# 12         $0.00      $309.30                  $0.00                    0
# 13         $0.00        $0.00                  $0.00                    0
# 14         $0.00    $1,667.52                  $0.00                    3
# 15         $0.00    $5,178.48                  $0.00                    3
# 16           NaN   $50,000.00                  $0.00                   57
# 17         $0.00  coming soon                  $0.00                    1
# 18         $0.00      $750.00                  $0.00                    6
# 19           NaN      $520.56                  $0.00                    1
# 20         $0.00    $2,413.26                  $0.00                    6
# 21         $0.00        $0.00                  $0.00                    0
# 22           NaN      $601.06                $704.94                   11
# 23           NaN        $5.00                  $0.00                    1
# 24           NaN        $0.00                  $0.00                    1
# 25           NaN        $0.00                  $0.00                    1
# 26           NaN        $0.00                  $0.00                    1
# 27           NaN        $0.00                  $0.00                    0
# 28           NaN       $32.35                  $0.00                    1
# 29           NaN        $0.00                  $0.00                    0
# 30           NaN        $0.00                  $0.00                    0
# 31       $635.06          NaN                    NaN                  NaN
# 32           NaN          NaN                    NaN                  NaN
# 33           NaN          NaN                    NaN                  NaN
# 34           NaN          NaN                    NaN                  NaN
# 35         $0.00          NaN                    NaN                  NaN
# 36            --          NaN                    NaN                  NaN
# 37       $250.00          NaN                    NaN                  NaN
# 38         $0.00          NaN                    NaN                  NaN
# 39         $0.00          NaN                    NaN                  NaN
# 40         $0.00          NaN                    NaN                  NaN
# 41           NaN          NaN                    NaN                  NaN
#
#    Expenses FY20 Income FY20 In-Kind Donations FY20  Volunteer Hours FY20
# 0          $0.00  $25,213.95                  $0.00                  75.0
# 1          $0.00   $3,610.00                  $3.50                  20.0
# 2          $0.00  $25,295.00                $341.23                  20.0
# 3        $224.92   $9,637.11                $459.55                  20.0
# 4         $25.50   $8,544.94              $1,499.08                  36.0
# 5        $302.00   $1,268.00                  $7.50                  50.0
# 6          $0.00   $1,115.00                $230.00                  30.0
# 7          $0.00     $400.00                  $0.00                   8.0
# 8            NaN   $4,010.00                $540.13                 300.0
# 9            NaN   $2,825.00                  $0.00                   0.0
# 10           NaN  $11,491.00              $9,552.59                 300.0
# 11       $167.14     $309.00                 $22.00                  10.0
# 12       $316.00   $2,920.00              $3,578.27                  60.0
# 13        $24.14   $1,213.60                  $0.00                  80.0
# 14         $0.00   $6,049.31                  $0.00                   3.0
# 15         $0.00  $30,005.66                  $0.00                   3.0
# 16           NaN  $87,500.00                  $0.00                  30.0
# 17         $0.00   $1,016.00                  $0.00                   1.0
# 18         $0.00       $0.00                  $0.00                   1.0
# 19           NaN     $500.00                  $0.00                   1.0
# 20         $0.00   $1,769.19                  $0.00                   6.0
# 21        $25.00   $5,487.46                  $0.00                   NaN
# 22           NaN   $1,183.00                $159.60                  10.0
# 23           NaN       $5.00                  $0.00                   1.0
# 24           NaN       $0.00                  $0.00                  10.0
# 25           NaN       $0.00                  $0.00                   1.0
# 26           NaN      $40.00                  $0.00                  10.0
# 27           NaN     $414.00                  $0.00                   4.0
# 28           NaN     $192.33                  $0.00                   1.0
# 29           NaN       $0.00                  $0.00                   0.0
# 30           NaN       $0.00                  $0.00                   0.0
# 31     $4,691.33         NaN                    NaN                   NaN
# 32        $50.00         NaN                    NaN                   NaN
# 33        $98.54         NaN                    NaN                   NaN
# 34       4038.95         NaN                    NaN                   NaN
# 35       $386.63         NaN                    NaN                   NaN
# 36            --         NaN                    NaN                   NaN
# 37     $3,220.00         NaN                    NaN                   NaN
# 38     see above         NaN                    NaN                   NaN
# 39         $0.00         NaN                    NaN                   NaN
# 40         $0.00         NaN                    NaN                   NaN
# 41        $48.54         NaN                    NaN                   NaN

# %%
# income_vs_expense['Campaign Name'].unique()

# %%
del income_vs_expense['Bucket']

x = income_vs_expense.set_index(['Campaign Name'])

Campaigns_to_Analyze = x.loc[['Appeal - June', 'Online appeal - Giving Tuesday', 'Ecua vols/visitors', 'Benefit dinner item sales', 'Benefit Dinner (occuring April 2020) (SPANS TWO FYs)', 'Benefit dinner tickets', 'Benefit dinner individual donations', 'Benefit dinner auction', 'Benefit dinner sponsorships (5)', 'Benefit dinner sponsorships (1)']]

Campaigns_to_Analyze.replace(regex=['coming soon'], value='0', inplace=True)
Campaigns_to_Analyze = Campaigns_to_Analyze.rename(index={'Online appeal - Giving Tuesday': 'Appeal - Giving Tuesday','Benefit dinner item sales': 'BD item sales', 'Benefit dinner tickets': 'BD tickets', 'Benefit dinner individual donations': 'BD individual donations', 'Benefit dinner auction': 'BD auction', 'Benefit dinner sponsorships (5)': 'BD major donors', 'Benefit dinner sponsorships (1)': 'BD corporate sponsorship'})

Campaigns_to_Analyze
# Out:
#                                                    Expenses FY21 Income FY21  \
# Campaign Name
# Appeal - June                                            $210.06   $9,641.00
# Appeal - Giving Tuesday                                    $0.00           0
# Ecua vols/visitors                                         $0.00       $0.00
# BD item sales                                                NaN     $601.06
# Benefit Dinner (occuring April 2020) (SPANS TWO...       $250.00         NaN
# BD tickets                                                   NaN   $4,817.12
# BD individual donations                                      NaN   $8,250.40
# BD auction                                                   NaN   $9,808.13
# BD major donors                                              NaN  $50,000.00
# BD corporate sponsorship                                     NaN     $520.56
#
#                                                    In-Kind Donations FY21  \
# Campaign Name
# Appeal - June                                                       $0.00
# Appeal - Giving Tuesday                                             $0.00
# Ecua vols/visitors                                                  $0.00
# BD item sales                                                     $704.94
# Benefit Dinner (occuring April 2020) (SPANS TWO...                    NaN
# BD tickets                                                        $384.79
# BD individual donations                                             $0.00
# BD auction                                                      $9,243.06
# BD major donors                                                     $0.00
# BD corporate sponsorship                                            $0.00
#
#                                                    Volunteer Hours FY21  \
# Campaign Name
# Appeal - June                                                        27
# Appeal - Giving Tuesday                                               0
# Ecua vols/visitors                                                    0
# BD item sales                                                        11
# Benefit Dinner (occuring April 2020) (SPANS TWO...                  NaN
# BD tickets                                                          538
# BD individual donations                                               0
# BD auction                                                          152
# BD major donors                                                      57
# BD corporate sponsorship                                              1
#
#                                                    Expenses FY20 Income FY20  \
# Campaign Name
# Appeal - June                                              $0.00  $25,295.00
# Appeal - Giving Tuesday                                   $25.50   $8,544.94
# Ecua vols/visitors                                        $25.00   $5,487.46
# BD item sales                                                NaN   $1,183.00
# Benefit Dinner (occuring April 2020) (SPANS TWO...     $3,220.00         NaN
# BD tickets                                                   NaN   $4,010.00
# BD individual donations                                      NaN   $2,825.00
# BD auction                                                   NaN  $11,491.00
# BD major donors                                              NaN  $87,500.00
# BD corporate sponsorship                                     NaN     $500.00
#
#                                                    In-Kind Donations FY20  \
# Campaign Name
# Appeal - June                                                     $341.23
# Appeal - Giving Tuesday                                         $1,499.08
# Ecua vols/visitors                                                  $0.00
# BD item sales                                                     $159.60
# Benefit Dinner (occuring April 2020) (SPANS TWO...                    NaN
# BD tickets                                                        $540.13
# BD individual donations                                             $0.00
# BD auction                                                      $9,552.59
# BD major donors                                                     $0.00
# BD corporate sponsorship                                            $0.00
#
#                                                     Volunteer Hours FY20
# Campaign Name
# Appeal - June                                                       20.0
# Appeal - Giving Tuesday                                             36.0
# Ecua vols/visitors                                                   NaN
# BD item sales                                                       10.0
# Benefit Dinner (occuring April 2020) (SPANS TWO...                   NaN
# BD tickets                                                         300.0
# BD individual donations                                              0.0
# BD auction                                                         300.0
# BD major donors                                                     30.0
# BD corporate sponsorship                                             1.0

# %% [markdown]
# # Data Cleaning
#
# ## Giving Tuesday FY20 (Copy)

# %%
Giving_Tuesday = Campaigns_to_Analyze.iloc[1:2,:]
Giving_Tuesday = Giving_Tuesday[['Income FY20', 'In-Kind Donations FY20', 'Volunteer Hours FY20', 'Expenses FY20', ]].replace('[\$,]', '', regex=True).astype(float)
Giving_Tuesday
# Out:
#                          Income FY20  In-Kind Donations FY20  \
# Campaign Name
# Appeal - Giving Tuesday      8544.94                 1499.08
#
#                          Volunteer Hours FY20  Expenses FY20
# Campaign Name
# Appeal - Giving Tuesday                  36.0           25.5

# %% [markdown]
# ## Ecuador Volunteers FY20

# %%
Ecua_vols = Campaigns_to_Analyze.iloc[2:3,:]
FY20expenses = Ecua_vols.iloc[0,4]

Ecua_vols = Ecua_vols[['Income FY20', 'In-Kind Donations FY20']]
Ecua_vols['Volunteer Hours FY20'] = 0
Ecua_vols['Expenses FY20'] = FY20expenses
Ecua_vols = Ecua_vols.replace('[\$,]', '', regex=True).astype(float)
Ecua_vols
# Out:
#                     Income FY20  In-Kind Donations FY20  Volunteer Hours FY20  \
# Campaign Name
# Ecua vols/visitors      5487.46                     0.0                   0.0
#
#                     Expenses FY20
# Campaign Name
# Ecua vols/visitors           25.0

# %% [markdown]
# ## Benefit Dinner FY20

# %%
Dinner_item_sales20 = Campaigns_to_Analyze.iloc[3:4,:]
Dinner_item_sales20 = Dinner_item_sales20[['Income FY20', 'In-Kind Donations FY20', 'Volunteer Hours FY20']].replace('[\$,]', '', regex=True).astype(float)
Dinner_item_sales20['Expenses FY20'] = 1


Benefit_Dinner_Expenses20 = Campaigns_to_Analyze.iloc[4:5,:]
Benefit_Dinner_Expenses20 = Benefit_Dinner_Expenses20[['Expenses FY20']].replace('[\$,]', '', regex=True).astype(float)


Benefit_Dinner_Income20 = Campaigns_to_Analyze.iloc[5:,:]
Benefit_Dinner_Income20 = Benefit_Dinner_Income20[['Income FY20', 'In-Kind Donations FY20', 'Volunteer Hours FY20']].replace('[\$,]', '', regex=True).astype(float)
Benefit_Dinner_Income20.loc['Benefit Dinner Totals'] = Benefit_Dinner_Income20.sum()

Benefit_Dinner20 = Benefit_Dinner_Income20.iloc[5:,:]
dinner_expenses_FY20 = Benefit_Dinner_Expenses20.iloc[0,0]
Benefit_Dinner20['Expenses FY20'] = dinner_expenses_FY20 
Benefit_Dinner20
# Out:
# C:\Users\Purvi Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                        Income FY20  In-Kind Donations FY20  \
# Campaign Name
# Benefit Dinner Totals     106326.0                10092.72
#
#                        Volunteer Hours FY20  Expenses FY20
# Campaign Name
# Benefit Dinner Totals                 631.0         3220.0

# %% [markdown]
# ## June Appeal FY21

# %%
June_Appeal = Campaigns_to_Analyze.iloc[0:1,:]
# June_Appeal = June_Appeal[June_Appeal.columns[0:8]].replace('[\$,]', '', regex=True).astype(float)
June_Appeal = June_Appeal[['Income FY21', 'In-Kind Donations FY21', 'Volunteer Hours FY21', 'Expenses FY21', ]].replace('[\$,]', '', regex=True).astype(float)
June_Appeal
# Out:
#                Income FY21  In-Kind Donations FY21  Volunteer Hours FY21  \
# Campaign Name
# Appeal - June       9641.0                     0.0                  27.0
#
#                Expenses FY21
# Campaign Name
# Appeal - June         210.06

# %% [markdown]
# ## Benfit Dinner Item Sales FY21

# %%
Dinner_item_sales = Campaigns_to_Analyze.iloc[3:4,:]
Dinner_item_sales = Dinner_item_sales[['Income FY21', 'In-Kind Donations FY21', 'Volunteer Hours FY21']].replace('[\$,]', '', regex=True).astype(float)
Dinner_item_sales['Expenses FY21'] = 1
Dinner_item_sales
# Out:
#                Income FY21  In-Kind Donations FY21  Volunteer Hours FY21  \
# Campaign Name
# BD item sales       601.06                  704.94                  11.0
#
#                Expenses FY21
# Campaign Name
# BD item sales              1

# %% [markdown]
# ## Other Dinner Line Items, FY21

# %%
Benefit_Dinner_Expenses = Campaigns_to_Analyze.iloc[4:5,:]
Benefit_Dinner_Expenses = Benefit_Dinner_Expenses[['Expenses FY21']].replace('[\$,]', '', regex=True).astype(float)
Benefit_Dinner_Expenses
# Out:
#                                                     Expenses FY21
# Campaign Name
# Benefit Dinner (occuring April 2020) (SPANS TWO...          250.0

# %%
Benefit_Dinner_Income = Campaigns_to_Analyze.iloc[5:,:]
Benefit_Dinner_Income = Benefit_Dinner_Income[['Income FY21', 'In-Kind Donations FY21', 'Volunteer Hours FY21']].replace('[\$,]', '', regex=True).astype(float)
Benefit_Dinner_Income.loc['Benefit Dinner Totals'] = Benefit_Dinner_Income.sum()
Benefit_Dinner_Income
# Out:
#                           Income FY21  In-Kind Donations FY21  \
# Campaign Name
# BD tickets                    4817.12                  384.79
# BD individual donations       8250.40                    0.00
# BD auction                    9808.13                 9243.06
# BD major donors              50000.00                    0.00
# BD corporate sponsorship       520.56                    0.00
# Benefit Dinner Totals        73396.21                 9627.85
#
#                           Volunteer Hours FY21
# Campaign Name
# BD tickets                               538.0
# BD individual donations                    0.0
# BD auction                               152.0
# BD major donors                           57.0
# BD corporate sponsorship                   1.0
# Benefit Dinner Totals                    748.0

# %%
Benefit_Dinner = Benefit_Dinner_Income.iloc[5:,:]
dinner_expenses_FY21 = Benefit_Dinner_Expenses.iloc[0,0]
Benefit_Dinner['Expenses FY21'] = dinner_expenses_FY21 
Benefit_Dinner
# Out:
# C:\Users\Purvi Patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                        Income FY21  In-Kind Donations FY21  \
# Campaign Name
# Benefit Dinner Totals     73396.21                 9627.85
#
#                        Volunteer Hours FY21  Expenses FY21
# Campaign Name
# Benefit Dinner Totals                 748.0          250.0

# %% [markdown]
# # ANALYSIS: FY21

# %%
x = [June_Appeal, Dinner_item_sales, Benefit_Dinner]
FY21_Campaigns = pd.concat(x)
FY21_Campaigns['Return_per_Dollar'] = FY21_Campaigns['Income FY21']/FY21_Campaigns['Expenses FY21']
FY21_Campaigns['Return_per_Hour'] = FY21_Campaigns['Income FY21']/FY21_Campaigns['Volunteer Hours FY21']
FY21_Campaigns
# Out:
#                        Income FY21  In-Kind Donations FY21  \
# Campaign Name
# Appeal - June              9641.00                    0.00
# BD item sales               601.06                  704.94
# Benefit Dinner Totals     73396.21                 9627.85
#
#                        Volunteer Hours FY21  Expenses FY21  Return_per_Dollar  \
# Campaign Name
# Appeal - June                          27.0         210.06          45.896411
# BD item sales                          11.0           1.00         601.060000
# Benefit Dinner Totals                 748.0         250.00         293.584840
#
#                        Return_per_Hour
# Campaign Name
# Appeal - June               357.074074
# BD item sales                54.641818
# Benefit Dinner Totals        98.123275

# %% [markdown]
# ## ANALYSIS: Return per Dollar Spent

# %%
return_per_dollar = FY21_Campaigns['Return_per_Dollar']
campaign = FY21_Campaigns.index

plt.figure(figsize=(5,5))
plt.bar(campaign, return_per_dollar, color=sb.hls_palette(10, l=.5))
plt.title("FY21 - Return per Dollar Spent")
plt.xlabel("Campaign")
plt.ylabel("Donations per Dollar Spent (USD)")
plt.xticks(rotation=45, ha='right')

# plt.savefig("./Images/FY21 - Return per Dollar Spent.png")
plt.show()

# %% [markdown]
# ## ANALYSIS: Return per Hour Volunteered

# %%
return_per_hour = FY21_Campaigns['Return_per_Hour']
campaign = FY21_Campaigns.index

plt.figure(figsize=(5,5))
plt.bar(campaign, return_per_hour, color=sb.hls_palette(10, l=.5))
plt.title("FY21 - Return per Hour Volunteered")
plt.xlabel("Campaign")
plt.ylabel("Donations per Hour (USD)")
plt.xticks(rotation=45, ha='right')

# plt.savefig("./Images/FY21 - Return per Volunteer Hour.png")
plt.show()

# %% [markdown]
# # ANALYSIS: FY20

# %%
y = [Giving_Tuesday, Benefit_Dinner20, Ecua_vols]
FY20_Campaigns = pd.concat(y)
FY20_Campaigns['Return_per_Dollar'] = FY20_Campaigns['Income FY20']/FY20_Campaigns['Expenses FY20']
FY20_Campaigns['Return_per_Hour'] = FY20_Campaigns['Income FY20']/FY20_Campaigns['Volunteer Hours FY20']
FY20_Campaigns
# Out:
#                          Income FY20  In-Kind Donations FY20  \
# Campaign Name
# Appeal - Giving Tuesday      8544.94                 1499.08
# Benefit Dinner Totals      106326.00                10092.72
# Ecua vols/visitors           5487.46                    0.00
#
#                          Volunteer Hours FY20  Expenses FY20  \
# Campaign Name
# Appeal - Giving Tuesday                  36.0           25.5
# Benefit Dinner Totals                   631.0         3220.0
# Ecua vols/visitors                        0.0           25.0
#
#                          Return_per_Dollar  Return_per_Hour
# Campaign Name
# Appeal - Giving Tuesday         335.095686       237.359444
# Benefit Dinner Totals            33.020497       168.503962
# Ecua vols/visitors              219.498400              inf

# %% [markdown]
# ## ANALYSIS: Return per Dollar Spent

# %%
return_per_dollar2 = FY20_Campaigns['Return_per_Dollar']
campaign2 = FY20_Campaigns.index

plt.figure(figsize=(5,5))
plt.bar(campaign2, return_per_dollar2, color=sb.hls_palette(10, l=.5))
plt.title("FY20 - Return per Dollar Spent")
plt.xlabel("Campaign")
plt.ylabel("Donations per Dollar Spent (USD)")
plt.xticks(rotation=45, ha='right')

# plt.savefig("./Images/FY20 - Return per Dollar Spent.png")
plt.show()

# %% [markdown]
# ## ANALYSIS: Return per Hour Volunteered

# %%
return_per_hour2 = FY20_Campaigns['Return_per_Hour']
campaign2 = FY20_Campaigns.index

plt.figure(figsize=(3,5))
plt.bar(campaign2, return_per_hour2, color=sb.hls_palette(10, l=.5))
plt.title("FY20 - Return per Hour Volunteered")
plt.xlabel("Campaign")
plt.ylabel("Donations per Hour (USD)")
plt.xticks(rotation=45, ha='right')

# plt.savefig("./Images/FY20 - Return per Volunteer Hour.png")
plt.show()
