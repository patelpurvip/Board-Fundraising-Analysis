# %% [markdown]
# # Non-Profit Org donation income by month

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

Starfish_monthly_donations = "Starfish_data_monthly_income_by_FY.csv"
starfish_data = pd.read_csv(Starfish_monthly_donations)

# %%
starfish_data.head()
# Out:
#      FY        April         May         June         July       August  \
# 0  FY15  $10,186.46   $1,401.27    $5,227.32    $8,971.53   $14,566.87
# 1  FY16  $13,142.04   $3,411.41    $7,615.61   $19,220.64    $5,928.25
# 2  FY17  $15,958.20   $7,640.55    $7,741.50   $10,241.60    $5,387.55
# 3  FY18  $25,398.18   $6,634.32   $17,131.36    $9,936.50    $8,769.53
# 4  FY19  $28,576.33   $4,721.55    $3,573.14    $8,591.17   $11,444.92
#
#      September      October     November     December      January  \
# 0   $6,401.00    $4,301.00      $899.93   $13,723.05   $20,355.00
# 1  $18,355.00    $5,921.23   $19,196.30   $25,008.29    $3,616.66
# 2   $8,101.91   $80,701.15   $12,063.94   $11,937.71    $7,866.00
# 3  $77,415.00    $6,444.19    $9,070.67   $38,717.80    $4,461.70
# 4  $69,055.56   $32,943.97    $6,015.42   $18,838.74    $3,472.01
#
#       Februay        March Unnamed: 13
# 0  $1,006.50   $11,441.38          NaN
# 1  $4,207.51   $12,504.90          NaN
# ...

# %%
starfish_data.dtypes
# Out:
# FY             object
# April          object
# May            object
# June           object
# July           object
# August         object
# September      object
# October        object
# November       object
# December       object
# January        object
# Februay        object
# March          object
# Unnamed: 13    object
# dtype: object

# %%
starfish_df = starfish_data.set_index(['FY'])
starfish_df = starfish_df.rename(columns={"Februay":"February"})
starfish_df
# Out:
#             April          May         June         July       August  \
# FY
# FY15  $10,186.46    $1,401.27    $5,227.32    $8,971.53   $14,566.87
# FY16  $13,142.04    $3,411.41    $7,615.61   $19,220.64    $5,928.25
# FY17  $15,958.20    $7,640.55    $7,741.50   $10,241.60    $5,387.55
# FY18  $25,398.18    $6,634.32   $17,131.36    $9,936.50    $8,769.53
# FY19  $28,576.33    $4,721.55    $3,573.14    $8,591.17   $11,444.92
# FY20  $25,885.48    $9,652.82   $28,958.72    $5,612.86    $4,206.09
# FY21  $30,985.03   $11,252.93   $11,598.30    $7,443.45    $9,400.30
#
#         September      October     November     December      January  \
# FY
# FY15   $6,401.00    $4,301.00      $899.93   $13,723.05   $20,355.00
# FY16  $18,355.00    $5,921.23   $19,196.30   $25,008.29    $3,616.66
# FY17   $8,101.91   $80,701.15   $12,063.94   $11,937.71    $7,866.00
# FY18  $77,415.00    $6,444.19    $9,070.67   $38,717.80    $4,461.70
# ...

# %%
starfish_df[starfish_df.columns[0:]] = starfish_df[starfish_df.columns[0:]].replace('[\$,]', '', regex=True).astype(float)
starfish_df
# Out:
#          April       May      June      July    August  September   October  \
# FY
# FY15  10186.46   1401.27   5227.32   8971.53  14566.87    6401.00   4301.00
# FY16  13142.04   3411.41   7615.61  19220.64   5928.25   18355.00   5921.23
# FY17  15958.20   7640.55   7741.50  10241.60   5387.55    8101.91  80701.15
# FY18  25398.18   6634.32  17131.36   9936.50   8769.53   77415.00   6444.19
# FY19  28576.33   4721.55   3573.14   8591.17  11444.92   69055.56  32943.97
# FY20  25885.48   9652.82  28958.72   5612.86   4206.09   36681.30  34069.73
# FY21  30985.03  11252.93  11598.30   7443.45   9400.30    9481.87  11466.97
#
#       November  December   January  February     March  Unnamed: 13
# FY
# FY15    899.93  13723.05  20355.00   1006.50  11441.38          NaN
# FY16  19196.30  25008.29   3616.66   4207.51  12504.90          NaN
# FY17  12063.94  11937.71   7866.00   8526.81   8298.20          NaN
# FY18   9070.67  38717.80   4461.70   4063.13  20382.79          NaN
# ...

# %%
starfish_df.dtypes
# Out:
# April          float64
# May            float64
# June           float64
# July           float64
# August         float64
# September      float64
# October        float64
# November       float64
# December       float64
# January        float64
# February       float64
# March          float64
# Unnamed: 13    float64
# dtype: object

# %%
starfish_df = starfish_df[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']] 
starfish_df
# Out:
#        January  February     March     April       May      June      July  \
# FY
# FY15  20355.00   1006.50  11441.38  10186.46   1401.27   5227.32   8971.53
# FY16   3616.66   4207.51  12504.90  13142.04   3411.41   7615.61  19220.64
# FY17   7866.00   8526.81   8298.20  15958.20   7640.55   7741.50  10241.60
# FY18   4461.70   4063.13  20382.79  25398.18   6634.32  17131.36   9936.50
# FY19   3472.01   4717.02  14472.35  28576.33   4721.55   3573.14   8591.17
# FY20   4435.72   4275.70  12302.85  25885.48   9652.82  28958.72   5612.86
# FY21   5913.06  14036.10  44758.87  30985.03  11252.93  11598.30   7443.45
#
#         August  September   October  November  December
# FY
# FY15  14566.87    6401.00   4301.00    899.93  13723.05
# FY16   5928.25   18355.00   5921.23  19196.30  25008.29
# FY17   5387.55    8101.91  80701.15  12063.94  11937.71
# FY18   8769.53   77415.00   6444.19   9070.67  38717.80
# FY19  11444.92   69055.56  32943.97   6015.42  18838.74
# ...

# %%
FY15 = starfish_df.iloc[0]
FY16 = starfish_df.iloc[1]
FY17 = starfish_df.iloc[2]
FY18 = starfish_df.iloc[3]
FY19 = starfish_df.iloc[4]
FY20 = starfish_df.iloc[5]
FY21 = starfish_df.iloc[6]

# %%
# FY15_array = FY15.to_list()
# FY16_array = FY16.to_list()
# FY17_array = FY17.to_list()
# FY18_array = FY18.to_list()
# FY19_array = FY19.to_list()
# FY20_array = FY20.to_list()
# FY21_array = FY21.to_list()

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

fig = plt.figure(figsize=(10,6))

plt.plot(months, FY15, color="blue", label="FY15")
plt.plot(months, FY16, color="red", label="FY16")
plt.plot(months, FY17, color="green", label="FY17")
plt.plot(months, FY18, color="orange", label="FY18")
plt.plot(months, FY19, color="black", label="FY19")
plt.plot(months, FY20, color="lime", label="FY20")
plt.plot(months, FY21, color="magenta", label="FY21")

plt.title("Donations by FY")
plt.xlabel("Month in Fiscal Year")
plt.ylabel("Donations Received ($USD)")


plt.xticks(months, rotation=45)
plt.legend(loc="upper left")

plt.savefig("./Images/Starfish_fundraising_by_FY.png")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))

plt.plot(months, FY15, color="blue", label="FY15")
plt.plot(months, FY16, color="red", label="FY16")


plt.title("Donations by FY")
plt.xlabel("Month in Fiscal Year")
plt.ylabel("Donations Received ($USD)")


plt.xticks(months, rotation=45)
plt.legend(loc="upper left")

plt.savefig("./Images/FY15-FY16.png")
plt.show()

# %%
fig = plt.figure(figsize=(10,6))

plt.plot(months, FY17, color="green", label="FY17")
plt.plot(months, FY18, color="orange", label="FY18")
plt.plot(months, FY19, color="black", label="FY19")
plt.plot(months, FY20, color="lime", label="FY20")
plt.plot(months, FY21, color="magenta", label="FY21")

plt.title("Donations by FY")
plt.xlabel("Month in Fiscal Year")
plt.ylabel("Donations Received ($USD)")


plt.xticks(months, rotation=45)
plt.legend(loc="upper left")

plt.savefig("./Images/FY17-FY21.png")
plt.show()

# %%
ave_monthly = starfish_df.mean()
ave_monthly
# Out:
# January       7160.021429
# February      5833.252857
# March        17737.334286
# April        21447.388571
# May           6387.835714
# June         11692.278571
# July         10002.535714
# August        8529.072857
# September    32213.091429
# October      25121.177143
# November      8052.478571
# December     22813.344286
# dtype: float64

# %%
fig = plt.figure(figsize=(10,6))

plt.plot(months, ave_monthly, color="blue", label="Monthly Ave Donations")


plt.title("Average Monthly Donations: FY15-FY21")
plt.xlabel("Month in Calendar Year")
plt.ylabel("Donations Received ($USD)")


plt.xticks(months, rotation=45)

plt.savefig("./Images/Ave_FY15-FY21.png")
plt.show()

# %%
historic_df = starfish_df.iloc[:6,:]
# historic_df

historic_monthly_ave = historic_df.mean()
historic_monthly_ave
# Out:
# January       7367.848333
# February      4466.111667
# March        13233.745000
# April        19857.781667
# May           5576.986667
# June         11707.941667
# July         10429.050000
# August        8383.868333
# September    36001.628333
# October      27396.878333
# November      8671.423333
# December     21405.093333
# dtype: float64

# %%
fig = plt.figure(figsize=(10,6))

plt.plot(months, historic_monthly_ave, color="blue", label="Monthly Ave FY15-FY20")
plt.plot(months, FY21, color="magenta", label="FY21")

plt.title("Average Monthly Donations: FY15-FY20")
plt.xlabel("Month in Calendar Year")
plt.ylabel("Donations Received ($USD)")


plt.xticks(months, rotation=45)

plt.savefig("./Images/Ave_FY15-FY20_vs_FY21.png")
plt.show()
